# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from new_source.run import run_cases
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from run import run_cases
#
# File ~/personal/thesis/new_source/run.py:6
#       4 import os
#       5 # Updated imports to reflect the new module structure
# ----> 6 from .membership_functions import compute_membership_functions
#       7 from .similarity_metrics import calculate_all_similarity_metrics # Renamed function
#       8 from .fitness_evaluation import compute_fitness_metrics
#
# ImportError: attempted relative import with no known parent package

# %%
results_df = run_cases()
print(results_df)
# Out:
# Running all cases...
# Running Case 1 - Method: nd - Sigma: 0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p01/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: 0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p1/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: 0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p2/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: 0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p5/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p01/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p1/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p2/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p5/no_norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: 0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p01/norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: 0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p1/norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: 0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p2/norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: 0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p5/norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p01/norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p1/norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p2/norm/case_1_nd_emp_kde.png
# Running Case 1 - Method: nd - Sigma: r0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p5/norm/case_1_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p01/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p1/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p2/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p5/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p01/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p1/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p2/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p5/no_norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p01/norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p1/norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p2/norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: 0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p5/norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p01/norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p1/norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p2/norm/case_2_nd_emp_kde.png
# Running Case 2 - Method: nd - Sigma: r0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p5/norm/case_2_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p01/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p1/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p2/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p5/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p01/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p1/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p2/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p5/no_norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p01/norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p1/norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p2/norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: 0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p5/norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p01/norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p1/norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p2/norm/case_3_nd_emp_kde.png
# Running Case 3 - Method: nd - Sigma: r0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p5/norm/case_3_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p01/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p1/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p2/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p5/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p01/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p1/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p2/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p5/no_norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p01/norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p1/norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p2/norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: 0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p5/norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p01/norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p1/norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p2/norm/case_4_nd_emp_kde.png
# Running Case 4 - Method: nd - Sigma: r0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p5/norm/case_4_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p01/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p1/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p2/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p5/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p01/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p1/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p2/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p5/no_norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p01/norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p1/norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p2/norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: 0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p5/norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p01/norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p1/norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p2/norm/case_5_nd_emp_kde.png
# Running Case 5 - Method: nd - Sigma: r0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p5/norm/case_5_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p01/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p1/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p2/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_0p5/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.01 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p01/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.1 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p1/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.2 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p2/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.5 - Normalize: False - Empirical: kde
# Plot saved to: plots/sigma_r0p5/no_norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p01/norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p1/norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p2/norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: 0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_0p5/norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.01 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p01/norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.1 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p1/norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.2 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p2/norm/case_6_nd_emp_kde.png
# Running Case 6 - Method: nd - Sigma: r0.5 - Normalize: True - Empirical: kde
# Plot saved to: plots/sigma_r0p5/norm/case_6_nd_emp_kde.png
#     Case Method Sigma_Option     Sigma  Normalized Empirical_Method  \
# 0      1     nd         0.01  0.010000       False              kde
# 1      1     nd          0.1  0.100000       False              kde
# 2      1     nd          0.2  0.200000       False              kde
# 3      1     nd          0.5  0.500000       False              kde
# 4      1     nd        r0.01  0.290275       False              kde
# ..   ...    ...          ...       ...         ...              ...
# 91     6     nd          0.5  0.500000        True              kde
# 92     6     nd        r0.01  0.010000        True              kde
# 93     6     nd         r0.1  0.100000        True              kde
# 94     6     nd         r0.2  0.200000        True              kde
# 95     6     nd         r0.5  0.500000        True              kde
#
#     Std_Orig_S1  Range_Orig_S1  Std_Orig_S2  Range_Orig_S2  \
# 0      4.935166      29.027491     4.840800      30.827938
# 1      4.935166      29.027491     4.840800      30.827938
# 2      4.935166      29.027491     4.840800      30.827938
# 3      4.935166      29.027491     4.840800      30.827938
# 4      4.935166      29.027491     4.840800      30.827938
# ..          ...            ...          ...            ...
# 91   426.826067    3082.793817     4.770584      30.229764
# 92   426.826067    3082.793817     4.770584      30.229764
# 93   426.826067    3082.793817     4.770584      30.229764
# 94   426.826067    3082.793817     4.770584      30.229764
# 95   426.826067    3082.793817     4.770584      30.229764
#
#     Similarity_Overlap  Distance_Euclidean        MSE_s1  KL_Divergence_s1  \
# 0             0.232862            0.095311  5.679757e-06          2.029629
# 1             0.394122            0.051929  5.474235e-07          0.113109
# 2             0.400937            0.049427  2.553880e-07          0.042184
# 3             0.406137            0.047433  7.215950e-08          0.010210
# 4             0.402938            0.048535  1.654459e-07          0.024917
# ..                 ...                 ...           ...               ...
# 91            0.904571            0.004840  5.364150e-06          0.507303
# 92            0.511998            0.052759  4.689779e-07          0.027293
# 93            0.632733            0.028247  9.654299e-07          0.055088
# 94            0.746306            0.015255  2.863215e-06          0.212001
# 95            0.904571            0.004840  5.364150e-06          0.507303
#
#          AIC_s1       BIC_s1
# 0   6315.634206  6325.449717
# 1   5846.714316  5856.529826
# 2   5932.134160  5941.949671
# 3   5992.975654  6002.791165
# 4   5962.071600  5971.887111
# ..          ...          ...
# 91  -803.625370  -792.423565
# 92 -3261.346007 -3250.144202
# 93 -2720.550613 -2709.348808
# 94 -2015.099980 -2003.898175
# 95  -803.625370  -792.423565
#
# [96 rows x 16 columns]

# %%
norm_only_df = results_df[results_df['Normalized'] == True]

# %%
import pandas as pd
import numpy as np

# Assuming results_df is already loaded from running run_cases()

# --- Optional Filtering ---
# Uncomment the next line to filter for a specific normalization status (e.g., True)
# results_df_filtered = results_df[results_df['Normalized'] == True].copy()
# Or, use the full DataFrame:
results_df_filtered = results_df.copy()
# --------------------------

# # --- Remove relative sigma options ('r...') ---
# # Ensure the 'Sigma_Option' column is of string type first
# results_df_filtered['Sigma_Option'] = results_df_filtered['Sigma_Option'].astype(str)
# # Create a boolean mask for rows that start with 'r'
# mask_starts_with_r = results_df_filtered['Sigma_Option'].str.startswith('r').fillna(False)
# # Apply the mask using boolean indexing with '~' to keep rows that DO NOT start with 'r'
# results_df_filtered = results_df_filtered[~mask_starts_with_r].copy()
# --- End removal ---

# --- Simplify Grouping and Display Columns ---
# Initial columns, assuming Method='nd' and Empirical_Method='kde'
grouping_cols = ['Case', 'Normalized']
display_cols = ['Case', 'Normalized', 'Sigma_Option', 'Sigma']

# Check if 'Normalized' has only one unique value after potential filtering.
# If so, remove it from grouping and display cols as well.
if 'Normalized' in results_df_filtered.columns and results_df_filtered['Normalized'].nunique() == 1:
    grouping_cols.remove('Normalized')
    display_cols.remove('Normalized')
    print("Note: Analyzing results for a single normalization status.")
elif 'Normalized' not in results_df_filtered.columns and 'Normalized' in grouping_cols:
     # Handle case where it wasn't in the original df but was in default list
     grouping_cols.remove('Normalized')
     display_cols.remove('Normalized')
# ---------------------------------------------

# --- Get Top 2 based on metrics ---
# Group by the simplified columns
grouped = results_df_filtered.groupby(grouping_cols, group_keys=False)

top2_aic = grouped.apply(lambda x: x.sort_values('AIC_s1').head(2))
top2_bic = grouped.apply(lambda x: x.sort_values('BIC_s1').head(2))
top2_mse = grouped.apply(lambda x: x.sort_values('MSE_s1').head(2))
# top2_kl = grouped.apply(lambda x: x.sort_values('KL_Divergence_s1').head(2)) # Uncomment if needed

# --- Display simplified results ---
print(f"--- Top 2 Sigma options based on AIC (Method=nd, Empirical=kde) ---")
# Add the metric column itself to the display
print(top2_aic[display_cols + ['AIC_s1']])
print("-" * 50) # Separator

print(f"\n--- Top 2 Sigma options based on BIC (Method=nd, Empirical=kde) ---")
print(top2_bic[display_cols + ['BIC_s1']])
print("-" * 50) # Separator

print(f"\n--- Top 2 Sigma options based on MSE (Method=nd, Empirical=kde) ---")
print(top2_mse[display_cols + ['MSE_s1']])
print("-" * 50) # Separator

# print(f"\n--- Top 2 Sigma options based on KL Divergence (Method=nd, Empirical=kde) ---") # Uncomment if needed
# print(top2_kl[display_cols + ['KL_Divergence_s1']])
# print("-" * 50) # Separator
# Out:
# --- Top 2 Sigma options based on AIC (Method=nd, Empirical=kde) ---
#     Case  Normalized Sigma_Option       Sigma        AIC_s1
# 1      1       False          0.1    0.100000   5846.714316
# 2      1       False          0.2    0.200000   5932.134160
# 8      1        True         0.01    0.010000   -775.739464
# 12     1        True        r0.01    0.010000   -775.739464
# 17     2       False          0.1    0.100000   5914.826657
# 18     2       False          0.2    0.200000   5945.953722
# 24     2        True         0.01    0.010000   -775.739464
# 28     2        True        r0.01    0.010000   -775.739464
# 33     3       False          0.1    0.100000   5839.637278
# 34     3       False          0.2    0.200000   5930.527477
# 40     3        True         0.01    0.010000   -775.739464
# 44     3        True        r0.01    0.010000   -775.739464
# 49     4       False          0.1    0.100000   7113.168061
# 50     4       False          0.2    0.200000   7211.192183
# 56     4        True         0.01    0.010000  -1074.523608
# 60     4        True        r0.01    0.010000  -1074.523608
# 65     5       False          0.1    0.100000   7090.462704
# 66     5       False          0.2    0.200000   7204.823226
# 72     5        True         0.01    0.010000  -1074.523608
# 76     5        True        r0.01    0.010000  -1074.523608
# 84     6       False        r0.01   30.827938  28873.020186
# 85     6       False         r0.1  308.279382  29413.815579
# 88     6        True         0.01    0.010000  -3261.346007
# 92     6        True        r0.01    0.010000  -3261.346007
# --------------------------------------------------
#
# --- Top 2 Sigma options based on BIC (Method=nd, Empirical=kde) ---
#     Case  Normalized Sigma_Option       Sigma        BIC_s1
# 1      1       False          0.1    0.100000   5856.529826
# 2      1       False          0.2    0.200000   5941.949671
# 8      1        True         0.01    0.010000   -765.923953
# 12     1        True        r0.01    0.010000   -765.923953
# 17     2       False          0.1    0.100000   5924.642168
# 18     2       False          0.2    0.200000   5955.769233
# 24     2        True         0.01    0.010000   -765.923953
# 28     2        True        r0.01    0.010000   -765.923953
# 33     3       False          0.1    0.100000   5849.452789
# 34     3       False          0.2    0.200000   5940.342988
# 40     3        True         0.01    0.010000   -765.923953
# 44     3        True        r0.01    0.010000   -765.923953
# 49     4       False          0.1    0.100000   7122.983572
# 50     4       False          0.2    0.200000   7221.007694
# 56     4        True         0.01    0.010000  -1064.708098
# 60     4        True        r0.01    0.010000  -1064.708098
# 65     5       False          0.1    0.100000   7100.278214
# 66     5       False          0.2    0.200000   7214.638737
# 72     5        True         0.01    0.010000  -1064.708098
# 76     5        True        r0.01    0.010000  -1064.708098
# 84     6       False        r0.01   30.827938  28884.221991
# 85     6       False         r0.1  308.279382  29425.017384
# 88     6        True         0.01    0.010000  -3250.144202
# 92     6        True        r0.01    0.010000  -3250.144202
# --------------------------------------------------
#
# --- Top 2 Sigma options based on MSE (Method=nd, Empirical=kde) ---
#     Case  Normalized Sigma_Option       Sigma        MSE_s1
# 5      1       False         r0.1    2.902749  1.592607e-08
# 3      1       False          0.5    0.500000  7.215950e-08
# 9      1        True          0.1    0.100000  1.210792e-08
# 13     1        True         r0.1    0.100000  1.210792e-08
# 21     2       False         r0.1    2.902749  4.537841e-08
# 19     2       False          0.5    0.500000  1.999752e-07
# 25     2        True          0.1    0.100000  1.210792e-08
# 29     2        True         r0.1    0.100000  1.210792e-08
# 37     3       False         r0.1    2.902749  1.210792e-08
# 35     3       False          0.5    0.500000  5.785969e-08
# 41     3        True          0.1    0.100000  1.210792e-08
# 45     3        True         r0.1    0.100000  1.210792e-08
# 53     4       False         r0.1    6.765974  6.170168e-09
# 54     4       False         r0.2   13.531948  5.935213e-07
# 57     4        True          0.1    0.100000  5.067004e-09
# 61     4        True         r0.1    0.100000  5.067004e-09
# 69     5       False         r0.1    6.765974  5.067004e-09
# 70     5       False         r0.2   13.531948  4.766296e-07
# 73     5        True          0.1    0.100000  5.067004e-09
# 77     5        True         r0.1    0.100000  5.067004e-09
# 84     6       False        r0.01   30.827938  4.689779e-07
# 85     6       False         r0.1  308.279382  9.654299e-07
# 88     6        True         0.01    0.010000  4.689779e-07
# 92     6        True        r0.01    0.010000  4.689779e-07
# --------------------------------------------------
# /tmp/ipykernel_16312/1387134404.py:43: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top2_aic = grouped.apply(lambda x: x.sort_values('AIC_s1').head(2))
# /tmp/ipykernel_16312/1387134404.py:44: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top2_bic = grouped.apply(lambda x: x.sort_values('BIC_s1').head(2))
# /tmp/ipykernel_16312/1387134404.py:45: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top2_mse = grouped.apply(lambda x: x.sort_values('MSE_s1').head(2))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Filter data for a specific case and method

df_case = results_df[
    (results_df['Normalized'] == False) &
    (results_df['Empirical_Method'] == 'counts')
]

# Calculate the means across the same Sigma_Option
df_case = df_case[['Similarity_Overlap', 'Distance_Euclidean',
                   'MSE_s1', 'KL_Divergence_s1', 'AIC_s1', 'BIC_s1', 'Sigma_Option', 'Method']].groupby(['Sigma_Option', 'Method']).mean().reset_index()

fig, axes = plt.subplots(2, 3, figsize=(18, 10))  # 2 rows, 3 columns
axes = axes.flatten()  # Flatten the axes array for easy indexing

# Define the metric names
metrics = ['Similarity_Overlap', 'Distance_Euclidean', 'MSE_s1', 
           'KL_Divergence_s1', 'AIC_s1', 'BIC_s1']

# Plot each metric in a separate subplot
for i, metric in enumerate(metrics):
    sns.stripplot(data=df_case, x='Sigma_Option', y=metric, ax=axes[i], hue="Method", marker='o')
    axes[i].set_title(f'{metric} vs. Sigma_Option')
    axes[i].set_xlabel('Sigma_Option')
    axes[i].set_ylabel(metric)
    axes[i].tick_params(axis='x', rotation=45)  # Rotate x-axis labels for better readability

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()
